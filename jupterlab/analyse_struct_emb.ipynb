# %% [markdown]
# # Analyzation of PPI Structure Embeddings #

# %%
import h5py
import os
import numpy as np
import pandas as pd

# %%
OUT_DIR = "/home/gavrilev/DLResearchPPI/PPI Research/src_/embeddings/ppi struct/"
dataset = "dataset1"  # replace with actual dataset name
output_path = os.path.join(OUT_DIR, f"{dataset}_processed_matrix_data.h5")

# %%
ppi_emb = h5py.File(output_path, "r")

# %%
ppi_emb.keys()
# Out:
# <KeysViewHDF5 ['conditional', 'full_mean', 'subset_mean']>

# %%
ppi_emb['conditional'].keys()
# Out:
# <KeysViewHDF5 ['0', '1', '2', '3', '4']>

# %%
list(ppi_emb['conditional'].keys())[0]
# Out:
# '0'

# %%
import random

# %%
random.choice(list(ppi_emb['conditional'].keys()))
# Out:
# '2'

# %%
ppi_emb['conditional']['1']['PPI_fa16e6f36653'].keys()
# Out:
# <KeysViewHDF5 ['mean_ifeature_omega_a', 'mean_ifeature_omega_b', 'mean_ppi_former_a', 'mean_ppi_former_b', 'progres_vector']>

# %%
ppi_emb['conditional']['1']['PPI_12d05c728240']['mean_ppi_former_a'][:].shape
# Out:
# (128,)

# %%
with h5py.File(output_path, "r") as hf:

    # ── 1. Top-level overview ────────────────────────────────────────────────
    print("=== Top-level keys (strategies) ===")
    print(list(hf.keys()))
    # e.g. ['conditional', 'full_mean', 'subset_mean']

    # ── 2. Models available under one strategy ───────────────────────────────
    strategy = "conditional"
    print(f"\n=== Models under '{strategy}' ===")
    print(list(hf[strategy].keys()))
    # e.g. ['model_1', 'model_2']

    # ── 3. PPI IDs available under one model ────────────────────────────────
    model = list(hf[strategy].keys())[0]   # grab first model dynamically
    print(f"\n=== First 5 PPI IDs under '{strategy}/{model}' ===")
    ppi_ids = list(hf[strategy][model].keys())
    print(ppi_ids[:5])

    # ── 4. Features stored for a single PPI ─────────────────────────────────
    ppi_id = ppi_ids[0]
    print(f"\n=== Features stored for '{strategy}/{model}/{ppi_id}' ===")
    print(list(hf[strategy][model][ppi_id].keys()))
    # e.g. ['mean_ifeature_omega_a', 'mean_ifeature_omega_b',
    #        'mean_ppi_former_a', 'mean_ppi_former_b', 'progres_vector']

    # ── 5. Read a single feature array ──────────────────────────────────────
    mean_a = hf[strategy][model][ppi_id]["mean_ppi_former_a"][:]
    print(f"\n=== mean_ppi_former_a for '{ppi_id}' ===")
    print(f"  shape : {mean_a.shape}")
    print(f"  dtype : {mean_a.dtype}")
    print(f"  values: {mean_a}")

    # ── 6. Compare same PPI across all three strategies ──────────────────────
    print(f"\n=== mean_ppi_former_a across strategies for '{ppi_id}' ===")
    for strat in hf.keys():
        arr = hf[strat][model][ppi_id]["mean_ppi_former_a"][:]
        print(f"  [{strat}]  shape={arr.shape}  mean={arr.mean():.6f}  std={arr.std():.6f}")

    # ── 7. Verify progres_vector is hard-linked (same data, no duplication) ──
    print(f"\n=== progres_vector hard-link verification for '{ppi_id}' ===")
    pv_conditional = hf["conditional"][model][ppi_id]["progres_vector"][:]
    pv_full_mean   = hf["full_mean"][model][ppi_id]["progres_vector"][:]
    pv_subset_mean = hf["subset_mean"][model][ppi_id]["progres_vector"][:]
    print(f"  conditional vs full_mean  identical: {np.array_equal(pv_conditional, pv_full_mean)}")
    print(f"  conditional vs subset_mean identical: {np.array_equal(pv_conditional, pv_subset_mean)}")

    # ── 8. Iterate over all PPIs for one strategy/model ─────────────────────
    print(f"\n=== Iterating all PPIs under '{strategy}/{model}' ===")
    for pid in list(hf[strategy][model].keys())[:3]:   # first 3 as a sample
        grp = hf[strategy][model][pid]
        pf_a = grp["mean_ppi_former_a"][:]
        pf_b = grp["mean_ppi_former_b"][:]
        prog = grp["progres_vector"][:]
        print(f"  ppi_id={pid:20s}  pf_a.shape={pf_a.shape}  pf_b.shape={pf_b.shape}  progres.shape={prog.shape}")

    # ── 9. Load everything into memory as a nested dict (mirrors old pickle) ──
    print(f"\n=== Loading full strategy into memory dict ===")
    def h5_to_dict(h5file, strategy):
        result = {}
        for model_key in h5file[strategy].keys():
            result[model_key] = {}
            for ppi_key in h5file[strategy][model_key].keys():
                result[model_key][ppi_key] = {
                    feat: h5file[strategy][model_key][ppi_key][feat][:]
                    for feat in h5file[strategy][model_key][ppi_key].keys()
                }
        return result

    data = h5_to_dict(hf, "conditional")
    print(f"  models loaded : {list(data.keys())}")
    print(f"  PPIs in first model: {len(data[list(data.keys())[0]])}")
# Out:
# === Top-level keys (strategies) ===
# ['conditional', 'full_mean', 'subset_mean']
#
# === Models under 'conditional' ===
# ['0', '1', '2', '3', '4']
#
# === First 5 PPI IDs under 'conditional/0' ===
# ['PPI_0047e4ad5eb3', 'PPI_007c40544bc3', 'PPI_01064eef6d15', 'PPI_03c834f4a8a5', 'PPI_048adb43bf11']
#
# === Features stored for 'conditional/0/PPI_0047e4ad5eb3' ===
# ['mean_ifeature_omega_a', 'mean_ifeature_omega_b', 'mean_ppi_former_a', 'mean_ppi_former_b', 'progres_vector']
#
# === mean_ppi_former_a for 'PPI_0047e4ad5eb3' ===
#   shape : (128,)
#   dtype : float32
#   values: [ 7.24408388e-01  4.09946889e-01  4.09135595e-03 -2.24461719e-01
#   1.05068356e-01  3.43034625e-01 -1.61502028e+00 -5.31472027e-01
#  -1.45498335e-01 -1.29182339e-01  1.27880812e+00 -1.86070189e-01
#   2.56806105e-01  5.27966022e-01 -2.73448378e-01  5.46542943e-01
#   3.20396721e-01 -1.38446555e-01  1.66569757e+00 -3.06220800e-01
#   6.14966512e-01  1.22257197e+00  6.33701980e-01  7.62202367e-02
#   1.48952520e+00  9.96464640e-02 -1.25745669e-01 -9.27077591e-01
#   3.86287086e-02 -3.66815478e-01  4.67672110e-01  9.85483885e-01
#  -2.41332722e+00 -6.03766143e-01  1.64479972e-03  3.23009640e-02
#  -1.95153151e-02  1.46851137e-01 -6.18212558e-02 -3.05641323e-01
#   2.36140996e-01 -5.85598528e-01 -2.44643480e-01  3.78645062e-01
#  -4.51719090e-02  8.20947066e-02  3.21154714e-01  1.73392132e-01
#   3.25198084e-01  1.85090587e-01  4.81076166e-02  9.59242508e-02
#  -1.07168846e-01 -1.40223861e+00 -1.96189702e-01  2.67863542e-01
#   5.85725904e-01  5.99827804e-02 -5.21685407e-02 -2.66157150e-01
#   2.81790912e-01 -9.34633389e-02  1.23948503e+00 -9.37094241e-02
#  -2.55234689e-01 -2.63845801e-01 -4.48338300e-01 -2.88230032e-01
#   4.80605774e-02 -2.21736297e-01 -4.26685452e-01  3.26123148e-01
#   1.55330431e+00 -2.92183042e-01  2.75013745e-01 -1.14770003e-01
#   8.88144076e-01 -4.55983669e-01  1.68251157e+00  4.31724846e-01
#   1.21172868e-01  1.05743304e-01 -3.75124216e-01 -6.05026901e-01
#  -2.43943244e-01 -1.50008872e-02 -1.74156249e-01  7.60286868e-01
#  -5.49306870e-01  3.74312133e-01 -3.81074429e-01 -7.36559272e-01
#   3.79545726e-02  9.62515026e-02  1.09309030e+00  1.00143604e-01
#  -3.13783675e-01 -1.20959571e-02 -3.19793850e-01 -4.45742428e-01
#  -5.10505915e-01  8.10176507e-02  1.81066024e+00  2.29002431e-01
#   2.94099271e-01 -4.68948573e-01  1.67039856e-01 -1.03255764e-01
#  -7.36236095e-01 -1.08718507e-01 -4.02890965e-02 -5.51548488e-02
#   1.45250276e-01  7.44322598e-01  6.34217620e-01  3.69220704e-01
#   2.20830321e+00  3.35805893e-01  4.25795376e-01 -7.23712966e-02
#  -1.31797080e-03  5.42312503e-01  7.24366978e-02 -1.82540774e-01
#  -1.50092691e-01  5.91303170e-01 -1.34123921e-01  7.91399088e-03]
#
# === mean_ppi_former_a across strategies for 'PPI_0047e4ad5eb3' ===
#   [conditional]  shape=(128,)  mean=0.092679  std=0.618431
#   [full_mean]  shape=(128,)  mean=0.092679  std=0.618431
#   [subset_mean]  shape=(128,)  mean=0.097333  std=0.608992
#
# === progres_vector hard-link verification for 'PPI_0047e4ad5eb3' ===
#   conditional vs full_mean  identical: True
#   conditional vs subset_mean identical: True
#
# === Iterating all PPIs under 'conditional/0' ===
#   ppi_id=PPI_0047e4ad5eb3      pf_a.shape=(128,)  pf_b.shape=(128,)  progres.shape=(128,)
#   ppi_id=PPI_007c40544bc3      pf_a.shape=(128,)  pf_b.shape=(128,)  progres.shape=(128,)
#   ppi_id=PPI_01064eef6d15      pf_a.shape=(128,)  pf_b.shape=(128,)  progres.shape=(128,)
#
# === Loading full strategy into memory dict ===
#   models loaded : ['0', '1', '2', '3', '4']
#   PPIs in first model: 187

# %%
with h5py.File(output_path, "r") as hf:
    ls = list(hf.keys())

# %%
ls
# Out:
# ['conditional', 'full_mean', 'subset_mean']

# %%
data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:1508, in _array_repr_implementation(arr, max_line_width, precision, suppress_small, array2string)
#    1506     lst = repr(arr.item())
#    1507 elif arr.size > 0 or arr.shape == (0,):
# -> 1508     lst = array2string(arr, max_line_width, precision, suppress_small,
#    1509                        ', ', prefix, suffix=suffix)
#    1510 else:  # show zero-length shape unless it is (0,)
#    1511     lst = "[], shape=%s" % (repr(arr.shape),)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:736, in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     733 if a.size == 0:
#     734     return "[]"
# --> 736 return _array2string(a, options, separator, prefix)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:513, in _recursive_guard.<locals>.decorating_function.<locals>.wrapper(self, *args, **kwargs)
#     511 repr_running.add(key)
#     512 try:
# --> 513     return f(self, *args, **kwargs)
#     514 finally:
#     515     repr_running.discard(key)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:539, in _array2string(a, options, separator, prefix)
#     536     summary_insert = ""
#     538 # find the right formatting function for the array
# --> 539 format_function = _get_format_function(data, **options)
#     541 # skip over "["
#     542 next_line_prefix = " "
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:472, in _get_format_function(data, **options)
#     470         return formatdict['longfloat']()
#     471     else:
# --> 472         return formatdict['float']()
#     473 elif issubclass(dtypeobj, _nt.complexfloating):
#     474     if issubclass(dtypeobj, _nt.clongfloat):
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:411, in _get_formatdict.<locals>.<lambda>()
#     403 def _get_formatdict(data, *, precision, floatmode, suppress, sign, legacy,
#     404                     formatter, **kwargs):
#     405     # note: extra arguments in kwargs are ignored
#     406
#     407     # wrapped in lambdas to avoid taking a code path with the wrong type of data
#     408     formatdict = {
#     409         'bool': lambda: BoolFormat(data),
#     410         'int': lambda: IntegerFormat(data),
# --> 411         'float': lambda: FloatingFormat(
#     412             data, precision, floatmode, suppress, sign, legacy=legacy),
#     413         'longfloat': lambda: FloatingFormat(
#     414             data, precision, floatmode, suppress, sign, legacy=legacy),
#     415         'complexfloat': lambda: ComplexFloatingFormat(
#     416             data, precision, floatmode, suppress, sign, legacy=legacy),
#     417         'longcomplexfloat': lambda: ComplexFloatingFormat(
#     418             data, precision, floatmode, suppress, sign, legacy=legacy),
#     419         'datetime': lambda: DatetimeFormat(data, legacy=legacy),
#     420         'timedelta': lambda: TimedeltaFormat(data),
#     421         'object': lambda: _object_format,
#     422         'void': lambda: str_format,
#     423         'numpystr': lambda: repr_format}
#     425     # we need to wrap values in `formatter` in a lambda, so that the interface
#     426     # is the same as the above values.
#     427     def indirect(x):
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:932, in FloatingFormat.__init__(self, data, precision, floatmode, suppress_small, sign, legacy)
#     929 self.exp_format = False
#     930 self.large_exponent = False
# --> 932 self.fillFormat(data)
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:963, in FloatingFormat.fillFormat(self, data)
#     959     trim, unique = 'k', False
#     960 strs = (dragon4_scientific(x, precision=self.precision,
#     961                    unique=unique, trim=trim, sign=self.sign == '+')
#     962         for x in finite_vals)
# --> 963 frac_strs, _, exp_strs = zip(*(s.partition('e') for s in strs))
#     964 int_part, frac_part = zip(*(s.split('.') for s in frac_strs))
#     965 self.exp_size = max(len(s) for s in exp_strs) - 1
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:963, in <genexpr>(.0)
#     959     trim, unique = 'k', False
#     960 strs = (dragon4_scientific(x, precision=self.precision,
#     961                    unique=unique, trim=trim, sign=self.sign == '+')
#     962         for x in finite_vals)
# --> 963 frac_strs, _, exp_strs = zip(*(s.partition('e') for s in strs))
#     964 int_part, frac_part = zip(*(s.split('.') for s in frac_strs))
#     965 self.exp_size = max(len(s) for s in exp_strs) - 1
#
# File ~/.conda/envs/chemprop/lib/python3.11/site-packages/numpy/core/arrayprint.py:960, in <genexpr>(.0)
#     958 if self.floatmode == 'fixed' or self._legacy <= 113:
#     959     trim, unique = 'k', False
# --> 960 strs = (dragon4_scientific(x, precision=self.precision,
#     961                    unique=unique, trim=trim, sign=self.sign == '+')
#     962         for x in finite_vals)
#     963 frac_strs, _, exp_strs = zip(*(s.partition('e') for s in strs))
#     964 int_part, frac_part = zip(*(s.split('.') for s in frac_strs))
#
# KeyboardInterrupt:
